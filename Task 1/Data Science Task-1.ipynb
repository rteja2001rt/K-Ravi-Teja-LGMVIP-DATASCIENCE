# %% [markdown]
# ##### K Ravi Teja
# #### Task-1
# #### Image to Pencil Sketch with Python

# %%
# !pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in c:\users\ravi\anaconda3\lib\site-packages (4.5.1.48)
# Requirement already satisfied: numpy>=1.14.5 in c:\users\ravi\anaconda3\lib\site-packages (from opencv-python) (1.19.5)

# %%
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
image = cv2.imread("akhil.jpg")
cv2.imshow("Shoto", image)
cv2.waitKey(0)
# Out:
# 27

# %%
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
plt.imshow(gray_image,cmap="gray")
plt.title("Black and White image")
# Out:
# Text(0.5, 1.0, 'Black and White image')

# %%
inverted_image = 255 - gray_image
plt.imshow(inverted_image,cmap="gray")
plt.title("Negative image")
# Out:
# Text(0.5, 1.0, 'Negative image')

# %%
blurred = cv2.GaussianBlur(inverted_image, (21, 21), 0)
inverted_blurred = 255 - blurred
plt.imshow(inverted_blurred,cmap="gray")
plt.title("Inverted GrayScale Image")
# Out:
# Text(0.5, 1.0, 'Inverted GrayScale Image')

# %%
pencil_sketch = cv2.divide(gray_image, inverted_blurred, scale=256.0)
plt.imshow(pencil_sketch,cmap="gray")
plt.title("Inverted Blurred GrayScale Image")
# Out:
# Text(0.5, 1.0, 'Inverted Blurred GrayScale Image')
